# %%
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\Utente\\Desktop\\Progetto Europee\\elezioni_europee_followers_leader_Europa_mv.csv", delimiter=";", encoding="unicode-escape")

# %%
data
# Out:
#                         Leader  Mi Piace        Data    Ora
# 0                  Theresa May    820927  10/04/2019  21:02
# 1              Guy Verhofstadt    369348  10/04/2019  21:02
# 2             Yanis Varoufakis    963932  10/04/2019  21:02
# 3                  Volt Europa      9340  10/04/2019  21:02
# 4                Marine Le Pen   2220368  10/04/2019  21:02
# 5              Emmanuel Macron   3804830  10/04/2019  21:02
# 6            Annalena Baerbock     33064  10/04/2019  21:02
# 7                Joerg Meuthen     39727  10/04/2019  21:02
# 8                Jeremy Corbyn   1944613  10/04/2019  21:02
# 9                  Theresa May    820964  10/04/2019  22:02
# 10             Guy Verhofstadt    369401  10/04/2019  22:02
# 11            Yanis Varoufakis    963931  10/04/2019  22:02
# 12                 Volt Europa      9344  10/04/2019  22:02
# 13               Marine Le Pen   2220373  10/04/2019  22:02
# 14             Emmanuel Macron   3804900  10/04/2019  22:02
# ...

# %%
may = data[data['Leader']=='Theresa May'].reset_index()
may = may.drop("index", axis=1)
may = may[may['Ora']=='20:02'].reset_index()
may = may.drop("index", axis=1)
# Out:
#          Leader  Mi Piace        Data    Ora
# 0   Theresa May    821989  11/04/2019  20:02
# 1   Theresa May    822743  12/04/2019  20:02
# 2   Theresa May    823292  13/04/2019  20:02
# 3   Theresa May    823685  14/04/2019  20:02
# 4   Theresa May    824081  15/04/2019  20:02
# 5   Theresa May    825759  16/04/2019  20:02
# 6   Theresa May    826315  17/04/2019  20:02
# 7   Theresa May    826749  18/04/2019  20:02
# 8   Theresa May    827160  19/04/2019  20:02
# 9   Theresa May    827593  20/04/2019  20:02
# 10  Theresa May    828896  21/04/2019  20:02
# 11  Theresa May    829908  22/04/2019  20:02
# 12  Theresa May    830559  23/04/2019  20:02
# 13  Theresa May    831040  24/04/2019  20:02
# 14  Theresa May    831468  25/04/2019  20:02
# 15  Theresa May    831817  26/04/2019  20:02
# 16  Theresa May    832183  27/04/2019  20:02
# 17  Theresa May    832487  28/04/2019  20:02
# 18  Theresa May    832820  29/04/2019  20:02
# 19  Theresa May    832996  30/04/2019  20:02
# ...

# %%
for index, row in may.iterrows():
    if index>=1:
        may['Delta'].iloc[index]= ((may.iloc[index, 1]-may.iloc[index-1, 1])/may.iloc[index-1, 1])*100
    else: may['Delta']= 0
# Out:
# C:\Users\Utente\AppData\Local\conda\conda\envs\python3.6\lib\site-packages\pandas\core\indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#          Leader  Mi Piace        Data    Ora     Delta
# 0   Theresa May    821989  11/04/2019  20:02  0.000000
# 1   Theresa May    822743  12/04/2019  20:02  0.091729
# 2   Theresa May    823292  13/04/2019  20:02  0.066728
# 3   Theresa May    823685  14/04/2019  20:02  0.047735
# 4   Theresa May    824081  15/04/2019  20:02  0.048077
# 5   Theresa May    825759  16/04/2019  20:02  0.203621
# 6   Theresa May    826315  17/04/2019  20:02  0.067332
# 7   Theresa May    826749  18/04/2019  20:02  0.052522
# 8   Theresa May    827160  19/04/2019  20:02  0.049713
# 9   Theresa May    827593  20/04/2019  20:02  0.052348
# ...

# %%
guy = data[data['Leader']=='Guy Verhofstadt'].reset_index()
guy = guy.drop("index", axis=1)
guy = guy[guy['Ora']=='20:02'].reset_index()
guy = guy.drop("index", axis=1)
for index, row in guy.iterrows():
    if index>=1:
        guy['Delta'].iloc[index]= ((guy.iloc[index, 1]-guy.iloc[index-1, 1])/guy.iloc[index-1, 1])*100
    else: guy['Delta']= 0
guy
# Out:
#              Leader  Mi Piace        Data    Ora     Delta
# 0   Guy Verhofstadt    369837  11/04/2019  20:02  0.000000
# 1   Guy Verhofstadt    370071  12/04/2019  20:02  0.063271
# 2   Guy Verhofstadt    370216  13/04/2019  20:02  0.039182
# 3   Guy Verhofstadt    370414  14/04/2019  20:02  0.053482
# 4   Guy Verhofstadt    370619  15/04/2019  20:02  0.055343
# 5   Guy Verhofstadt    370854  16/04/2019  20:02  0.063407
# 6   Guy Verhofstadt    371178  17/04/2019  20:02  0.087366
# 7   Guy Verhofstadt    371400  18/04/2019  20:02  0.059810
# 8   Guy Verhofstadt    371559  19/04/2019  20:02  0.042811
# 9   Guy Verhofstadt    371676  20/04/2019  20:02  0.031489
# 10  Guy Verhofstadt    371778  21/04/2019  20:02  0.027443
# 11  Guy Verhofstadt    371930  22/04/2019  20:02  0.040885
# 12  Guy Verhofstadt    372058  23/04/2019  20:02  0.034415
# 13  Guy Verhofstadt    372184  24/04/2019  20:02  0.033866
# 14  Guy Verhofstadt    372336  25/04/2019  20:02  0.040840
# ...

# %%
yanis = data[data['Leader']=='Yanis Varoufakis'].reset_index()
yanis = yanis.drop("index", axis=1)
yanis = yanis[yanis['Ora']=='20:02'].reset_index()
yanis = yanis.drop("index", axis=1)
for index, row in yanis.iterrows():
    if index>=1:
        yanis['Delta'].iloc[index]= ((yanis.iloc[index, 1]-yanis.iloc[index-1, 1])/yanis.iloc[index-1, 1])*100
    else: yanis['Delta']= 0
yanis
# Out:
#               Leader  Mi Piace        Data    Ora     Delta
# 0   Yanis Varoufakis    964848  11/04/2019  20:02  0.000000
# 1   Yanis Varoufakis    965896  12/04/2019  20:02  0.108618
# 2   Yanis Varoufakis    966365  13/04/2019  20:02  0.048556
# 3   Yanis Varoufakis    966551  14/04/2019  20:02  0.019247
# 4   Yanis Varoufakis    966635  15/04/2019  20:02  0.008691
# 5   Yanis Varoufakis    966791  16/04/2019  20:02  0.016138
# 6   Yanis Varoufakis    966928  17/04/2019  20:02  0.014171
# 7   Yanis Varoufakis    967032  18/04/2019  20:02  0.010756
# 8   Yanis Varoufakis    967168  19/04/2019  20:02  0.014064
# 9   Yanis Varoufakis    967303  20/04/2019  20:02  0.013958
# 10  Yanis Varoufakis    967731  21/04/2019  20:02  0.044247
# 11  Yanis Varoufakis    967967  22/04/2019  20:02  0.024387
# 12  Yanis Varoufakis    968004  23/04/2019  20:02  0.003822
# 13  Yanis Varoufakis    968099  24/04/2019  20:02  0.009814
# 14  Yanis Varoufakis    968209  25/04/2019  20:02  0.011362
# ...

# %%
lepen = data[data['Leader']=='Marine Le Pen'].reset_index()
lepen = lepen.drop("index", axis=1)
lepen = lepen[lepen['Ora']=='20:02'].reset_index()
lepen = lepen.drop("index", axis=1)
for index, row in lepen.iterrows():
    if index>=1:
        lepen['Delta'].iloc[index]= ((lepen.iloc[index, 1]-lepen.iloc[index-1, 1])/lepen.iloc[index-1, 1])*100
    else: lepen['Delta']= 0
lepen
# Out:
#            Leader  Mi Piace        Data    Ora     Delta
# 0   Marine Le Pen   2220873  11/04/2019  20:02  0.000000
# 1   Marine Le Pen   2221449  12/04/2019  20:02  0.025936
# 2   Marine Le Pen   2221916  13/04/2019  20:02  0.021022
# 3   Marine Le Pen   2222368  14/04/2019  20:02  0.020343
# 4   Marine Le Pen   2222938  15/04/2019  20:02  0.025648
# 5   Marine Le Pen   2225017  16/04/2019  20:02  0.093525
# 6   Marine Le Pen   2225848  17/04/2019  20:02  0.037348
# 7   Marine Le Pen   2226423  18/04/2019  20:02  0.025833
# 8   Marine Le Pen   2226961  19/04/2019  20:02  0.024164
# 9   Marine Le Pen   2227378  20/04/2019  20:02  0.018725
# 10  Marine Le Pen   2227915  21/04/2019  20:02  0.024109
# 11  Marine Le Pen   2228436  22/04/2019  20:02  0.023385
# 12  Marine Le Pen   2228894  23/04/2019  20:02  0.020553
# 13  Marine Le Pen   2229355  24/04/2019  20:02  0.020683
# 14  Marine Le Pen   2229944  25/04/2019  20:02  0.026420
# ...

# %%
macron = data[data['Leader']=='Emmanuel Macron'].reset_index()
macron = macron.drop("index", axis=1)
macron = macron[macron['Ora']=='20:02'].reset_index()
macron = macron.drop("index", axis=1)
for index, row in macron.iterrows():
    if index>=1:
        macron['Delta'].iloc[index]= ((macron.iloc[index, 1]-macron.iloc[index-1, 1])/macron.iloc[index-1, 1])*100
    else: macron['Delta']= 0
macron
# Out:
#              Leader  Mi Piace        Data    Ora     Delta
# 0   Emmanuel Macron   3806558  11/04/2019  20:02  0.000000
# 1   Emmanuel Macron   3808332  12/04/2019  20:02  0.046604
# 2   Emmanuel Macron   3810151  13/04/2019  20:02  0.047764
# 3   Emmanuel Macron   3811775  14/04/2019  20:02  0.042623
# 4   Emmanuel Macron   3814268  15/04/2019  20:02  0.065403
# 5   Emmanuel Macron   3849398  16/04/2019  20:02  0.921016
# 6   Emmanuel Macron   3855544  17/04/2019  20:02  0.159661
# 7   Emmanuel Macron   3859071  18/04/2019  20:02  0.091479
# 8   Emmanuel Macron   3861515  19/04/2019  20:02  0.063331
# 9   Emmanuel Macron   3864162  20/04/2019  20:02  0.068548
# 10  Emmanuel Macron   3867548  21/04/2019  20:02  0.087626
# 11  Emmanuel Macron   3870685  22/04/2019  20:02  0.081111
# 12  Emmanuel Macron   3873370  23/04/2019  20:02  0.069368
# 13  Emmanuel Macron   3876232  24/04/2019  20:02  0.073889
# 14  Emmanuel Macron   3879320  25/04/2019  20:02  0.079665
# ...

# %%
annalena = data[data['Leader']=='Annalena Baerbock'].reset_index()
annalena = annalena.drop("index", axis=1)
annalena = annalena[annalena['Ora']=='20:02'].reset_index()
annalena = annalena.drop("index", axis=1)
for index, row in annalena.iterrows():
    if index>=1:
        annalena['Delta'].iloc[index]= ((annalena.iloc[index, 1]-annalena.iloc[index-1, 1])/annalena.iloc[index-1, 1])*100
    else: annalena['Delta']= 0
annalena
# Out:
#                Leader  Mi Piace        Data    Ora     Delta
# 0   Annalena Baerbock     33086  11/04/2019  20:02  0.000000
# 1   Annalena Baerbock     33112  12/04/2019  20:02  0.078583
# 2   Annalena Baerbock     33148  13/04/2019  20:02  0.108722
# 3   Annalena Baerbock     33166  14/04/2019  20:02  0.054302
# 4   Annalena Baerbock     33182  15/04/2019  20:02  0.048242
# 5   Annalena Baerbock     33224  16/04/2019  20:02  0.126575
# 6   Annalena Baerbock     33258  17/04/2019  20:02  0.102336
# 7   Annalena Baerbock     33286  18/04/2019  20:02  0.084190
# 8   Annalena Baerbock     33314  19/04/2019  20:02  0.084119
# 9   Annalena Baerbock     33342  20/04/2019  20:02  0.084049
# 10  Annalena Baerbock     33363  21/04/2019  20:02  0.062984
# 11  Annalena Baerbock     33392  22/04/2019  20:02  0.086923
# 12  Annalena Baerbock     33400  23/04/2019  20:02  0.023958
# 13  Annalena Baerbock     33434  24/04/2019  20:02  0.101796
# ...

# %%
meuthen = data[data['Leader']=='Joerg Meuthen'].reset_index()
meuthen = meuthen.drop("index", axis=1)
meuthen = meuthen[meuthen['Ora']=='20:02'].reset_index()
meuthen = meuthen.drop("index", axis=1)
for index, row in meuthen.iterrows():
    if index>=1:
        meuthen['Delta'].iloc[index]= ((meuthen.iloc[index, 1]-meuthen.iloc[index-1, 1])/meuthen.iloc[index-1, 1])*100
    else: meuthen['Delta']= 0
meuthen
# Out:
#            Leader  Mi Piace        Data    Ora     Delta
# 0   Joerg Meuthen     39778  11/04/2019  20:02  0.000000
# 1   Joerg Meuthen     39815  12/04/2019  20:02  0.093016
# 2   Joerg Meuthen     39847  13/04/2019  20:02  0.080372
# 3   Joerg Meuthen     39890  14/04/2019  20:02  0.107913
# 4   Joerg Meuthen     39935  15/04/2019  20:02  0.112810
# 5   Joerg Meuthen     39992  16/04/2019  20:02  0.142732
# 6   Joerg Meuthen     40030  17/04/2019  20:02  0.095019
# 7   Joerg Meuthen     40063  18/04/2019  20:02  0.082438
# 8   Joerg Meuthen     40093  19/04/2019  20:02  0.074882
# 9   Joerg Meuthen     40132  20/04/2019  20:02  0.097274
# 10  Joerg Meuthen     40179  21/04/2019  20:02  0.117114
# 11  Joerg Meuthen     40220  22/04/2019  20:02  0.102043
# 12  Joerg Meuthen     40254  23/04/2019  20:02  0.084535
# 13  Joerg Meuthen     40297  24/04/2019  20:02  0.106822
# 14  Joerg Meuthen     40339  25/04/2019  20:02  0.104226
# ...

# %%
corbyn = data[data['Leader']=='Jeremy Corbyn'].reset_index()
corbyn = corbyn.drop("index", axis=1)
corbyn = corbyn[corbyn['Ora']=='20:02'].reset_index()
corbyn = corbyn.drop("index", axis=1)
for index, row in corbyn.iterrows():
    if index>=1:
        corbyn['Delta'].iloc[index]= ((corbyn.iloc[index, 1]-corbyn.iloc[index-1, 1])/corbyn.iloc[index-1, 1])*100
    else: corbyn['Delta']= 0
corbyn
# Out:
#            Leader  Mi Piace        Data    Ora     Delta
# 0   Jeremy Corbyn   1944951  11/04/2019  20:02  0.000000
# 1   Jeremy Corbyn   1947372  12/04/2019  20:02  0.124476
# 2   Jeremy Corbyn   1948177  13/04/2019  20:02  0.041338
# 3   Jeremy Corbyn   1948542  14/04/2019  20:02  0.018735
# 4   Jeremy Corbyn   1948872  15/04/2019  20:02  0.016936
# 5   Jeremy Corbyn   1949419  16/04/2019  20:02  0.028068
# 6   Jeremy Corbyn   1949955  17/04/2019  20:02  0.027495
# 7   Jeremy Corbyn   1950381  18/04/2019  20:02  0.021847
# 8   Jeremy Corbyn   1950720  19/04/2019  20:02  0.017381
# 9   Jeremy Corbyn   1951185  20/04/2019  20:02  0.023837
# 10  Jeremy Corbyn   1951816  21/04/2019  20:02  0.032339
# 11  Jeremy Corbyn   1952348  22/04/2019  20:02  0.027257
# 12  Jeremy Corbyn   1952696  23/04/2019  20:02  0.017825
# 13  Jeremy Corbyn   1953031  24/04/2019  20:02  0.017156
# 14  Jeremy Corbyn   1953196  25/04/2019  20:02  0.008448
# ...

# %%
bellamy = data[data['Leader']=='Francois-Xavier Bellamy'].reset_index()
bellamy = bellamy.drop("index", axis=1)
bellamy = bellamy[bellamy['Ora']=='20:02'].reset_index()
bellamy = bellamy.drop("index", axis=1)
for index, row in bellamy.iterrows():
    if index>=1:
        bellamy['Delta'].iloc[index]= ((bellamy.iloc[index, 1]-bellamy.iloc[index-1, 1])/bellamy.iloc[index-1, 1])*100
    else: bellamy['Delta']= 0
bellamy
# Out:
#                      Leader  Mi Piace        Data    Ora     Delta
# 0   Francois-Xavier Bellamy     32868  27/04/2019  20:02  0.000000
# 1   Francois-Xavier Bellamy     32960  28/04/2019  20:02  0.279908
# 2   Francois-Xavier Bellamy     33025  29/04/2019  20:02  0.197209
# 3   Francois-Xavier Bellamy     33113  30/04/2019  20:02  0.266465
# 4   Francois-Xavier Bellamy     33207  01/05/2019  20:02  0.283876
# 5   Francois-Xavier Bellamy     33319  02/05/2019  20:02  0.337278
# 6   Francois-Xavier Bellamy     33469  03/05/2019  20:02  0.450194
# 7   Francois-Xavier Bellamy     33616  04/05/2019  20:02  0.439212
# 8   Francois-Xavier Bellamy     33782  05/05/2019  20:02  0.493812
# 9   Francois-Xavier Bellamy     33944  06/05/2019  20:02  0.479545
# 10  Francois-Xavier Bellamy     34095  07/05/2019  20:02  0.444850
# 11  Francois-Xavier Bellamy     34251  08/05/2019  20:02  0.457545
# 12  Francois-Xavier Bellamy     34544  10/05/2019  20:02  0.855449
# ...

# %%
melenchon = data[data['Leader']=='Jean-Luc Melenchon'].reset_index()
melenchon = melenchon.drop("index", axis=1)
melenchon = melenchon[melenchon['Ora']=='20:02'].reset_index()
melenchon = melenchon.drop("index", axis=1)
for index, row in melenchon.iterrows():
    if index>=1:
        melenchon['Delta'].iloc[index]= ((melenchon.iloc[index, 1]-melenchon.iloc[index-1, 1])/melenchon.iloc[index-1, 1])*100
    else: melenchon['Delta']= 0
melenchon
# Out:
#                 Leader  Mi Piace        Data    Ora     Delta
# 0   Jean-Luc Melenchon   2027402  27/04/2019  20:02  0.000000
# 1   Jean-Luc Melenchon   2027876  28/04/2019  20:02  0.023380
# 2   Jean-Luc Melenchon   2028369  29/04/2019  20:02  0.024311
# 3   Jean-Luc Melenchon   2028729  30/04/2019  20:02  0.017748
# 4   Jean-Luc Melenchon   2029134  01/05/2019  20:02  0.019963
# 5   Jean-Luc Melenchon   2029662  02/05/2019  20:02  0.026021
# 6   Jean-Luc Melenchon   2030185  03/05/2019  20:02  0.025768
# 7   Jean-Luc Melenchon   2030605  04/05/2019  20:02  0.020688
# 8   Jean-Luc Melenchon   2031044  05/05/2019  20:02  0.021619
# 9   Jean-Luc Melenchon   2031439  06/05/2019  20:02  0.019448
# 10  Jean-Luc Melenchon   2032020  07/05/2019  20:02  0.028600
# 11  Jean-Luc Melenchon   2032562  08/05/2019  20:02  0.026673
# 12  Jean-Luc Melenchon   2033387  10/05/2019  20:02  0.040589
# 13  Jean-Luc Melenchon   2033559  11/05/2019  20:02  0.008459
# ...

# %%
nahles = data[data['Leader']=='Andrea Maria Nahles'].reset_index()
nahles = nahles.drop("index", axis=1)
nahles = nahles[nahles['Ora']=='20:02'].reset_index()
nahles = nahles.drop("index", axis=1)
for index, row in nahles.iterrows():
    if index>=1:
        nahles['Delta'].iloc[index]= ((nahles.iloc[index, 1]-nahles.iloc[index-1, 1])/nahles.iloc[index-1, 1])*100
    else: nahles['Delta']= 0
nahles
# Out:
#                  Leader  Mi Piace        Data    Ora     Delta
# 0   Andrea Maria Nahles   2027402  27/04/2019  20:02  0.000000
# 1   Andrea Maria Nahles   2027876  28/04/2019  20:02  0.023380
# 2   Andrea Maria Nahles   2028369  29/04/2019  20:02  0.024311
# 3   Andrea Maria Nahles   2028729  30/04/2019  20:02  0.017748
# 4   Andrea Maria Nahles   2029134  01/05/2019  20:02  0.019963
# 5   Andrea Maria Nahles   2029662  02/05/2019  20:02  0.026021
# 6   Andrea Maria Nahles   2030185  03/05/2019  20:02  0.025768
# 7   Andrea Maria Nahles   2030605  04/05/2019  20:02  0.020688
# 8   Andrea Maria Nahles   2031044  05/05/2019  20:02  0.021619
# 9   Andrea Maria Nahles   2031439  06/05/2019  20:02  0.019448
# 10  Andrea Maria Nahles   2032020  07/05/2019  20:02  0.028600
# 11  Andrea Maria Nahles   2032562  08/05/2019  20:02  0.026673
# 12  Andrea Maria Nahles   2033387  10/05/2019  20:02  0.040589
# 13  Andrea Maria Nahles   2033559  11/05/2019  20:02  0.008459
# ...

# %%
weidel = data[data['Leader']=='Alice Weidel'].reset_index()
weidel = weidel.drop("index", axis=1)
weidel = weidel[weidel['Ora']=='20:02'].reset_index()
weidel = weidel.drop("index", axis=1)
for index, row in weidel.iterrows():
    if index>=1:
        weidel['Delta'].iloc[index]= ((weidel.iloc[index, 1]-weidel.iloc[index-1, 1])/weidel.iloc[index-1, 1])*100
    else: weidel['Delta']= 0
weidel
# Out:
#           Leader  Mi Piace        Data    Ora     Delta
# 0   Alice Weidel     68095  27/04/2019  20:02  0.000000
# 1   Alice Weidel     68164  28/04/2019  20:02  0.101329
# 2   Alice Weidel     68203  29/04/2019  20:02  0.057215
# 3   Alice Weidel     68224  30/04/2019  20:02  0.030790
# 4   Alice Weidel     68270  01/05/2019  20:02  0.067425
# 5   Alice Weidel     68291  02/05/2019  20:02  0.030760
# 6   Alice Weidel     68335  03/05/2019  20:02  0.064430
# 7   Alice Weidel     68396  04/05/2019  20:02  0.089266
# 8   Alice Weidel     68504  05/05/2019  20:02  0.157904
# 9   Alice Weidel     68565  06/05/2019  20:02  0.089046
# 10  Alice Weidel     68614  07/05/2019  20:02  0.071465
# 11  Alice Weidel     68664  08/05/2019  20:02  0.072871
# 12  Alice Weidel     68751  10/05/2019  20:02  0.126704
# 13  Alice Weidel     68809  11/05/2019  20:02  0.084362
# 14  Alice Weidel     68878  12/05/2019  20:02  0.100278
# 15  Alice Weidel     68938  13/05/2019  20:02  0.087111
# ...

# %%
sturgeon = data[data['Leader']=='Nicola Sturgeon'].reset_index()
sturgeon = sturgeon.drop("index", axis=1)
sturgeon = sturgeon[sturgeon['Ora']=='20:02'].reset_index()
sturgeon = sturgeon.drop("index", axis=1)
for index, row in sturgeon.iterrows():
    if index>=1:
        sturgeon['Delta'].iloc[index]= ((sturgeon.iloc[index, 1]-sturgeon.iloc[index-1, 1])/sturgeon.iloc[index-1, 1])*100
    else: sturgeon['Delta']= 0
sturgeon
# Out:
#              Leader  Mi Piace        Data    Ora     Delta
# 0   Nicola Sturgeon    966965  27/04/2019  20:02  0.000000
# 1   Nicola Sturgeon    967089  28/04/2019  20:02  0.012824
# 2   Nicola Sturgeon    967323  29/04/2019  20:02  0.024196
# 3   Nicola Sturgeon    967412  30/04/2019  20:02  0.009201
# 4   Nicola Sturgeon    967506  01/05/2019  20:02  0.009717
# 5   Nicola Sturgeon    967604  02/05/2019  20:02  0.010129
# 6   Nicola Sturgeon    967723  03/05/2019  20:02  0.012298
# 7   Nicola Sturgeon    967886  04/05/2019  20:02  0.016844
# 8   Nicola Sturgeon    967937  05/05/2019  20:02  0.005269
# 9   Nicola Sturgeon    967964  06/05/2019  20:02  0.002789
# 10  Nicola Sturgeon    967962  07/05/2019  20:02 -0.000207
# 11  Nicola Sturgeon    967956  08/05/2019  20:02 -0.000620
# 12  Nicola Sturgeon    967999  10/05/2019  20:02  0.004442
# 13  Nicola Sturgeon    967977  11/05/2019  20:02 -0.002273
# 14  Nicola Sturgeon    968076  12/05/2019  20:02  0.010228
# ...

# %%
iglesias = data[data['Leader']=='Pablo Iglesias'].reset_index()
iglesias = iglesias.drop("index", axis=1)
iglesias = iglesias[iglesias['Ora']=='20:02'].reset_index()
iglesias = iglesias.drop("index", axis=1)
for index, row in iglesias.iterrows():
    if index>=1:
        iglesias['Delta'].iloc[index]= ((iglesias.iloc[index, 1]-iglesias.iloc[index-1, 1])/iglesias.iloc[index-1, 1])*100
    else: iglesias['Delta']= 0
iglesias
# Out:
#             Leader  Mi Piace        Data    Ora     Delta
# 0   Pablo Iglesias   2288095  27/04/2019  20:02  0.000000
# 1   Pablo Iglesias   2290921  28/04/2019  20:02  0.123509
# 2   Pablo Iglesias   2297437  29/04/2019  20:02  0.284427
# 3   Pablo Iglesias   2298932  30/04/2019  20:02  0.065073
# 4   Pablo Iglesias   2299887  01/05/2019  20:02  0.041541
# 5   Pablo Iglesias   2300642  02/05/2019  20:02  0.032828
# 6   Pablo Iglesias   2301176  03/05/2019  20:02  0.023211
# 7   Pablo Iglesias   2301532  04/05/2019  20:02  0.015470
# 8   Pablo Iglesias   2301866  05/05/2019  20:02  0.014512
# 9   Pablo Iglesias   2302139  06/05/2019  20:02  0.011860
# 10  Pablo Iglesias   2302469  07/05/2019  20:02  0.014334
# 11  Pablo Iglesias   2302968  08/05/2019  20:02  0.021672
# 12  Pablo Iglesias   2303581  10/05/2019  20:02  0.026618
# 13  Pablo Iglesias   2303981  11/05/2019  20:02  0.017364
# 14  Pablo Iglesias   2304342  12/05/2019  20:02  0.015669
# ...

# %%
sanchez = data[data['Leader']=='Pedro Sanchez'].reset_index()
sanchez = sanchez.drop("index", axis=1)
sanchez = sanchez[sanchez['Ora']=='20:02'].reset_index()
sanchez = sanchez.drop("index", axis=1)
for index, row in sanchez.iterrows():
    if index>=1:
        sanchez['Delta'].iloc[index]= ((sanchez.iloc[index, 1]-sanchez.iloc[index-1, 1])/sanchez.iloc[index-1, 1])*100
    else: sanchez['Delta']= 0
sanchez
# Out:
#            Leader  Mi Piace        Data    Ora     Delta
# 0   Pedro Sanchez   1012891  27/04/2019  20:02  0.000000
# 1   Pedro Sanchez   1014312  28/04/2019  20:02  0.140292
# 2   Pedro Sanchez   1025472  29/04/2019  20:02  1.100253
# 3   Pedro Sanchez   1028427  30/04/2019  20:02  0.288160
# 4   Pedro Sanchez   1030165  01/05/2019  20:02  0.168996
# 5   Pedro Sanchez   1031494  02/05/2019  20:02  0.129008
# 6   Pedro Sanchez   1032369  03/05/2019  20:02  0.084828
# 7   Pedro Sanchez   1032940  04/05/2019  20:02  0.055310
# 8   Pedro Sanchez   1033453  05/05/2019  20:02  0.049664
# 9   Pedro Sanchez   1033938  06/05/2019  20:02  0.046930
# 10  Pedro Sanchez   1034382  07/05/2019  20:02  0.042943
# 11  Pedro Sanchez   1035210  08/05/2019  20:02  0.080048
# 12  Pedro Sanchez   1036881  10/05/2019  20:02  0.161417
# 13  Pedro Sanchez   1037800  11/05/2019  20:02  0.088631
# 14  Pedro Sanchez   1038439  12/05/2019  20:02  0.061573
# ...

# %%
rivera = data[data['Leader']=='Albert Rivera'].reset_index()
rivera = rivera.drop("index", axis=1)
rivera = rivera[rivera['Ora']=='20:02'].reset_index()
rivera = rivera.drop("index", axis=1)
for index, row in rivera.iterrows():
    if index>=1:
        rivera['Delta'].iloc[index]= ((rivera.iloc[index, 1]-rivera.iloc[index-1, 1])/rivera.iloc[index-1, 1])*100
    else: rivera['Delta']= 0
rivera
# Out:
#            Leader  Mi Piace        Data    Ora     Delta
# 0   Albert Rivera   1123683  27/04/2019  20:02  0.000000
# 1   Albert Rivera   1125082  28/04/2019  20:02  0.124501
# 2   Albert Rivera   1128015  29/04/2019  20:02  0.260692
# 3   Albert Rivera   1129424  30/04/2019  20:02  0.124910
# 4   Albert Rivera   1130358  01/05/2019  20:02  0.082697
# 5   Albert Rivera   1131072  02/05/2019  20:02  0.063166
# 6   Albert Rivera   1131640  03/05/2019  20:02  0.050218
# 7   Albert Rivera   1131962  04/05/2019  20:02  0.028454
# 8   Albert Rivera   1132190  05/05/2019  20:02  0.020142
# 9   Albert Rivera   1132363  06/05/2019  20:02  0.015280
# 10  Albert Rivera   1132607  07/05/2019  20:02  0.021548
# 11  Albert Rivera   1132864  08/05/2019  20:02  0.022691
# 12  Albert Rivera   1133385  10/05/2019  20:02  0.045990
# 13  Albert Rivera   1133736  11/05/2019  20:02  0.030969
# 14  Albert Rivera   1133952  12/05/2019  20:02  0.019052
# ...

# %%
blanco = data[data['Leader']=='Pablo Casado Blanco'].reset_index()
blanco = blanco.drop("index", axis=1)
blanco = blanco[blanco['Ora']=='20:02'].reset_index()
blanco = blanco.drop("index", axis=1)
for index, row in blanco.iterrows():
    if index>=1:
        blanco['Delta'].iloc[index]= ((blanco.iloc[index, 1]-blanco.iloc[index-1, 1])/blanco.iloc[index-1, 1])*100
    else: blanco['Delta']= 0
blanco
# Out:
#                  Leader  Mi Piace        Data    Ora     Delta
# 0   Pablo Casado Blanco    239772  27/04/2019  20:02  0.000000
# 1   Pablo Casado Blanco    241182  28/04/2019  20:02  0.588059
# 2   Pablo Casado Blanco    242613  29/04/2019  20:02  0.593328
# 3   Pablo Casado Blanco    243365  30/04/2019  20:02  0.309959
# 4   Pablo Casado Blanco    243891  01/05/2019  20:02  0.216136
# 5   Pablo Casado Blanco    244171  02/05/2019  20:02  0.114805
# 6   Pablo Casado Blanco    244529  03/05/2019  20:02  0.146619
# 7   Pablo Casado Blanco    244793  04/05/2019  20:02  0.107963
# 8   Pablo Casado Blanco    244901  05/05/2019  20:02  0.044119
# 9   Pablo Casado Blanco    245012  06/05/2019  20:02  0.045324
# 10  Pablo Casado Blanco    245140  07/05/2019  20:02  0.052242
# 11  Pablo Casado Blanco    245307  08/05/2019  20:02  0.068124
# 12  Pablo Casado Blanco    245690  10/05/2019  20:02  0.156131
# 13  Pablo Casado Blanco    245924  11/05/2019  20:02  0.095242
# ...

# %%
farage = data[data['Leader']=='Nigel Farage'].reset_index()
farage = farage.drop("index", axis=1)
farage = farage[farage['Ora']=='20:02'].reset_index()
farage = farage.drop("index", axis=1)
for index, row in farage.iterrows():
    if index>=1:
        farage['Delta'].iloc[index]= ((farage.iloc[index, 1]-farage.iloc[index-1, 1])/farage.iloc[index-1, 1])*100
    else: farage['Delta']= 0
farage
# Out:
#           Leader  Mi Piace        Data    Ora     Delta
# 0   Nigel Farage   1298325  27/04/2019  20:02  0.000000
# 1   Nigel Farage   1298862  28/04/2019  20:02  0.041361
# 2   Nigel Farage   1299139  29/04/2019  20:02  0.021326
# 3   Nigel Farage   1299485  30/04/2019  20:02  0.026633
# 4   Nigel Farage   1299931  01/05/2019  20:02  0.034321
# 5   Nigel Farage   1300232  02/05/2019  20:02  0.023155
# 6   Nigel Farage   1300511  03/05/2019  20:02  0.021458
# 7   Nigel Farage   1300845  04/05/2019  20:02  0.025682
# 8   Nigel Farage   1301393  05/05/2019  20:02  0.042126
# 9   Nigel Farage   1301781  06/05/2019  20:02  0.029814
# 10  Nigel Farage   1302011  07/05/2019  20:02  0.017668
# 11  Nigel Farage   1302396  08/05/2019  20:02  0.029570
# 12  Nigel Farage   1303454  10/05/2019  20:02  0.081235
# 13  Nigel Farage   1303841  11/05/2019  20:02  0.029690
# 14  Nigel Farage   1305596  12/05/2019  20:02  0.134602
# 15  Nigel Farage   1307259  13/05/2019  20:02  0.127375
# ...

# %%
abascal = data[data['Leader']=='Santiago Abascal'].reset_index()
abascal = abascal.drop("index", axis=1)
abascal = abascal[abascal['Ora']=='20:02'].reset_index()
abascal = abascal.drop("index", axis=1)
for index, row in abascal.iterrows():
    if index>=1:
        abascal['Delta'].iloc[index]= ((abascal.iloc[index, 1]-abascal.iloc[index-1, 1])/abascal.iloc[index-1, 1])*100
    else: abascal['Delta']= 0
abascal
# Out:
#               Leader  Mi Piace        Data    Ora     Delta
# 0   Santiago Abascal    224449  28/04/2019  20:02  0.000000
# 1   Santiago Abascal    226306  29/04/2019  20:02  0.827359
# 2   Santiago Abascal    227366  30/04/2019  20:02  0.468392
# 3   Santiago Abascal    228137  01/05/2019  20:02  0.339101
# 4   Santiago Abascal    228619  02/05/2019  20:02  0.211277
# 5   Santiago Abascal    228974  03/05/2019  20:02  0.155280
# 6   Santiago Abascal    229144  04/05/2019  20:02  0.074244
# 7   Santiago Abascal    229278  05/05/2019  20:02  0.058479
# 8   Santiago Abascal    229330  06/05/2019  20:02  0.022680
# 9   Santiago Abascal    229451  07/05/2019  20:02  0.052762
# 10  Santiago Abascal    229543  08/05/2019  20:02  0.040096
# 11  Santiago Abascal    229655  10/05/2019  20:02  0.048793
# 12  Santiago Abascal    229784  11/05/2019  20:02  0.056171
# 13  Santiago Abascal    229881  12/05/2019  20:02  0.042214
# 14  Santiago Abascal    229954  13/05/2019  20:02  0.031756
# ...

# %%
data = may.append([guy,yanis,lepen,macron,annalena,meuthen,corbyn,bellamy,melenchon,nahles,weidel,sturgeon,iglesias,sanchez,rivera,blanco,farage,abascal]).reset_index()
data = data.drop('index', axis=1)
data = data.sort_values(['Data', 'Ora']).reset_index()
data = data.drop('index', axis=1)
data
# Out:
#                       Leader  Mi Piace        Data    Ora     Delta
# 0                Theresa May    833275  01/05/2019  20:02  0.033494
# 1            Guy Verhofstadt    374362  01/05/2019  20:02  0.075385
# 2           Yanis Varoufakis    968774  01/05/2019  20:02  0.028808
# 3              Marine Le Pen   2233018  01/05/2019  20:02  0.021097
# 4            Emmanuel Macron   3894627  01/05/2019  20:02  0.060556
# 5          Annalena Baerbock     33644  01/05/2019  20:02  0.080317
# 6              Joerg Meuthen     40627  01/05/2019  20:02  0.120755
# 7              Jeremy Corbyn   1956306  01/05/2019  20:02  0.019479
# 8    Francois-Xavier Bellamy     33207  01/05/2019  20:02  0.283876
# 9         Jean-Luc Melenchon   2029134  01/05/2019  20:02  0.019963
# 10       Andrea Maria Nahles   2029134  01/05/2019  20:02  0.019963
# 11              Alice Weidel     68270  01/05/2019  20:02  0.067425
# 12           Nicola Sturgeon    967506  01/05/2019  20:02  0.009717
# ...

# %%
data.to_csv("C:\\Users\\Utente\\Desktop\\Progetto Europee\\elezioni_europee_followers_leader_Europa_clean.csv", sep=';')
