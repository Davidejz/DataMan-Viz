# %%
# coding: utf-8

# In[1]:

from __future__ import absolute_import, print_function
import tweepy
from tweepy import OAuthHandler
from tweepy import Stream
import json


# In[2]:

with open("/home/maria_dev/dataman_viz/conf/secret.json", "r") as f:
    secret = json.load(f)
    consumer_key=secret["CONSUMER_KEY"]
    consumer_secret=secret["CONSUMER_SECRET"]

    access_token=secret["ACCESS_TOKEN"]
    access_token_secret=secret["ACCESS_TOKEN_SECRET"]

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

import datetime
now = datetime.datetime.now()

api.me().name


now.strftime("%d/%m/%Y")


may = api.get_user(screen_name = 'theresa_may')

may.followers_count


with open("/home/maria_dev/dataman_viz/data/elezioni_europee_followers_leader_Europa.csv", "a") as f:
    f.write('{};{};{};{}\n'.format("Theresa May", may.followers_count, now.strftime("%d/%m/%Y"), now.strftime("%H:%M")))


guyverhofstadt = api.get_user(screen_name = 'guyverhofstadt')


guyverhofstadt.followers_count


with open("/home/maria_dev/dataman_viz/data/elezioni_europee_followers_leader_Europa.csv", "a") as f:
    f.write('{};{};{};{}\n'.format("Guy Verhofstadt", guyverhofstadt.followers_count, now.strftime("%d/%m/%Y"), now.strftime("%H:%M")))


yanisvaroufakis = api.get_user(screen_name = 'yanisvaroufakis')


yanisvaroufakis.followers_count



with open("/home/maria_dev/dataman_viz/data/elezioni_europee_followers_leader_Europa.csv", "a") as f:
    f.write('{};{};{};{}\n'.format("Yanis Varoufakis", yanisvaroufakis.followers_count, now.strftime("%d/%m/%Y"), now.strftime("%H:%M")))


# In[15]:

volt = api.get_user(screen_name = 'VoltEuropa')


# In[16]:

volt.followers_count


# In[17]:

with open("/home/maria_dev/dataman_viz/data/elezioni_europee_followers_leader_Europa.csv", "a") as f:
    f.write('{};{};{};{}\n'.format("Volt Europa", volt.followers_count, now.strftime("%d/%m/%Y"), now.strftime("%H:%M")))


# In[18]:

MLP_officiel = api.get_user(screen_name = 'MLP_officiel')


# In[19]:

MLP_officiel.followers_count


# In[20]:

with open("/home/maria_dev/dataman_viz/data/elezioni_europee_followers_leader_Europa.csv", "a") as f:
    f.write('{};{};{};{}\n'.format("Marine Le Pen", MLP_officiel.followers_count, now.strftime("%d/%m/%Y"), now.strftime("%H:%M")))


# In[21]:

EmmanuelMacron = api.get_user(screen_name = 'EmmanuelMacron')


# In[22]:

EmmanuelMacron.followers_count


# In[23]:

with open("/home/maria_dev/dataman_viz/data/elezioni_europee_followers_leader_Europa.csv", "a") as f:
    f.write('{};{};{};{}\n'.format("Emmanuel Macron", EmmanuelMacron.followers_count, now.strftime("%d/%m/%Y"), now.strftime("%H:%M")))
    

ABaerbock = api.get_user(screen_name = 'ABaerbock')


# In[22]:

ABaerbock.followers_count


# In[23]:

with open("/home/maria_dev/dataman_viz/data/elezioni_europee_followers_leader_Europa.csv", "a") as f:
    f.write('{};{};{};{}\n'.format("Annalena Baerbock", ABaerbock.followers_count, now.strftime("%d/%m/%Y"), now.strftime("%H:%M")))


Joerg_Meuthen = api.get_user(screen_name = 'Joerg_Meuthen')


# In[22]:

Joerg_Meuthen.followers_count


# In[23]:

with open("/home/maria_dev/dataman_viz/data/elezioni_europee_followers_leader_Europa.csv", "a") as f:
    f.write('{};{};{};{}\n'.format("Joerg Meuthen", Joerg_Meuthen.followers_count, now.strftime("%d/%m/%Y"), now.strftime("%H:%M")))
    

jeremycorbyn = api.get_user(screen_name = 'jeremycorbyn')


# In[22]:

jeremycorbyn.followers_count


# In[23]:

with open("/home/maria_dev/dataman_viz/data/elezioni_europee_followers_leader_Europa.csv", "a") as f:
    f.write('{};{};{};{}\n'.format("Jeremy Corbyn", jeremycorbyn.followers_count, now.strftime("%d/%m/%Y"), now.strftime("%H:%M")))
